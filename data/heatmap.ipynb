# %%
import pandas as pd

data = [
    ('PHF8', 300.00, 300.00, 300.00, 82.07, 73.72, 8.40, 48.11, 0.02, 0.17, 0.00, 0.00),
    ('KMT2A', 300.00, 300.00, 300.00, 90.59, 43.56, 29.21, 36.22, 0.38, 0.80, 0.07, 0.80),
    ('MLL2', 300.00, 300.00, 165.83, 61.29, 40.83, 16.25, 15.03, 0.51, 0.00, 0.00, 0.00),
    ('AIRE', 300.00, 300.00, 82.30, 12.70, 9.10, 0.00, 11.10, 0.00, 0.00, 0.00, 0.00),
    ('RAG2', 300.00, 300.00, 300.00, 0.00, 0.00, 4.27, 1.97, 0.00, 1.47, 0.00, 0.00),
    ('ING4', 300.00, 300.00, 153.37, 84.89, 15.95, 28.81, 20.85, 0.07, 0.64, 0.77, 0.52),
    ('ZCWPW1', 300.00, 300.00, 10.60, 4.95, 1.38, 1.85, 2.70, 0.00, 0.00, 0.00, 0.00),
    ('TAF3', 300.00, 300.00, 74.88, 23.10, 16.86, 6.12, 6.23, 0.21, 0.00, 0.00, 0.00),
    ('WDR5', 300.00, 300.00, 300.00, 300.00, 166.32, 53.94, 45.91, 0.74, 1.46, 0.26, 0.59),
    ('CCDC101', 300.00, 300.00, 300.00, 92.40, 47.52, 0.00, 1.85, 0.00, 0.00, 0.00, 0.00),
    ('H2A', 90.306273, 83.340084, 80.974694, 68.630784, 66.185087, 56.610834, 62.051587, 3.000000, 0.823909, 0.000000, 0.397940),
    ('H2B', 86.545155, 82.939302, 70.732828, 58.481486, 64.277366, 48.718967, 56.512862, 0.000000, 0.769551, 0.000000, 0.000000),
    ('H3', 95.659556, 95.812479, 94.752027, 95.027334, 93.350665, 85.075204, 86.480172, 1.468521, 1.244125, 0.045757, 0.000000),
    ('H4', 66.962574, 67.119186, 67.946922, 67.095826, 67.211125, 44.707744, 51.966576, 4.085128, 4.480172, 0.000000, 1.161151)
]

columns = ['Gene', 'human', 'mouse', 'zebrafish', 'drosophila', 'c.elegans', 'ciliate', 'yeast', 'methanocaldococcus', 'thermococcus', 'e.coli', 'tuberculosis']

df = pd.DataFrame(data, columns=columns)
df = df.set_index('Gene')
df
# Out:
#               human       mouse   zebrafish  drosophila   c.elegans  \
# Gene
# PHF8     300.000000  300.000000  300.000000   82.070000   73.720000
# KMT2A    300.000000  300.000000  300.000000   90.590000   43.560000
# MLL2     300.000000  300.000000  165.830000   61.290000   40.830000
# AIRE     300.000000  300.000000   82.300000   12.700000    9.100000
# RAG2     300.000000  300.000000  300.000000    0.000000    0.000000
# ING4     300.000000  300.000000  153.370000   84.890000   15.950000
# ZCWPW1   300.000000  300.000000   10.600000    4.950000    1.380000
# TAF3     300.000000  300.000000   74.880000   23.100000   16.860000
# WDR5     300.000000  300.000000  300.000000  300.000000  166.320000
# CCDC101  300.000000  300.000000  300.000000   92.400000   47.520000
# H2A       90.306273   83.340084   80.974694   68.630784   66.185087
# H2B       86.545155   82.939302   70.732828   58.481486   64.277366
# H3        95.659556   95.812479   94.752027   95.027334   93.350665
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 5), dpi=300)
heatmap = sns.heatmap(df, cmap='Blues')
heatmap.yaxis.set_tick_params(labelsize=15)
heatmap.xaxis.set_tick_params(labelsize=15)
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=25, ha='right')
plt.ylabel("Gene", fontsize=18)
# Out:
# Text(587.1666666666667, 0.5, 'Gene')
